# %% [markdown]
# <a href="https://colab.research.google.com/github/felanders/sds-project/blob/main/sds-project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install.packages("rtweet")

# %%
library(haven)
library(dplyr)
library(rtweet)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
token <- get_token()

# %%
search_fullarchive("#fridays4future",n=500, fromDate = "201812010000",toDate = "201902010000", env_name = "SDSeth",token = token)
# Out:
# Linking to: OpenSSL 1.1.1  11 Sep 2018
# tweets/search/fullarchive/SDSeth ***
#     user_id             status_id           created_at          screen_name
# 1   948757031653138432  1091122528070840320 2019-01-31 23:54:17 Woody25987406
# 2   948757031653138432  1089230335366361088 2019-01-26 18:35:23 Woody25987406
# 3   149799081           1091111605042143232 2019-01-31 23:10:53 NoahsArkCrew
# 4   149799081           1091110532055220230 2019-01-31 23:06:37 NoahsArkCrew
# 5   149799081           1091109773486014469 2019-01-31 23:03:36 NoahsArkCrew
# 6   149799081           1089519511575900160 2019-01-27 13:44:28 NoahsArkCrew
# 7   149799081           1090286312949772288 2019-01-29 16:31:28 NoahsArkCrew
# 8   149799081           1090589489322430464 2019-01-30 12:36:11 NoahsArkCrew
# 9   536980961           1091110040558170112 2019-01-31 23:04:40 squig_
# 10  4141673686          1091109238011768832 2019-01-31 23:01:28 Galadriel1000
# ...

# %%
get_my_timeline()

# %%
get_timeline("florianklenk")
